# %%
import opendatasets as od
import pandas as pd
import numpy as np

# %%
# od.download('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-codebook.csv')
# Out:
# ...
# 24576it [00:03, 7870.17it/s]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Ochibobo\\Measuring_Carbon\\Jupyter_Notebooks'

# %%
owid = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-codebook.csv')
owid
# Out:
#                                  column  \
# 0                              iso_code
# 1                               country
# 2                                  year
# 3                                   co2
# 4                        co2_per_capita
# 5                             trade_co2
# 6                            cement_co2
# 7                 cement_co2_per_capita
# 8                              coal_co2
# 9                   coal_co2_per_capita
# 10                          flaring_co2
# 11               flaring_co2_per_capita
# 12                              gas_co2
# 13                   gas_co2_per_capita
# 14                              oil_co2
# 15                   oil_co2_per_capita
# 16                   other_industry_co2
# 17                 other_co2_per_capita
# 18                      co2_growth_prct
# 19                       co2_growth_abs
# 20                          co2_per_gdp
# 21                  co2_per_unit_energy
# ...

# %%
owid_df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')
owid_df
# Out:
#       iso_code      country  year     co2  co2_per_capita  trade_co2  \
# 0          AFG  Afghanistan  1949   0.015           0.002        NaN
# 1          AFG  Afghanistan  1950   0.084           0.011        NaN
# 2          AFG  Afghanistan  1951   0.092           0.012        NaN
# 3          AFG  Afghanistan  1952   0.092           0.012        NaN
# 4          AFG  Afghanistan  1953   0.106           0.013        NaN
# ...        ...          ...   ...     ...             ...        ...
# 25984      ZWE     Zimbabwe  2016  10.738           0.765      1.415
# 25985      ZWE     Zimbabwe  2017   9.582           0.673      1.666
# 25986      ZWE     Zimbabwe  2018  11.854           0.821      1.308
# 25987      ZWE     Zimbabwe  2019  10.949           0.748      1.473
# 25988      ZWE     Zimbabwe  2020  10.531           0.709        NaN
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# ...

# %%
# Subset by country & year > 2014
India_owid = owid_df[owid_df['country'] == 'India'][owid_df['year'] >= 2015]
India_owid
# Out:
# C:\Users\Ochibobo\AppData\Local\Temp\ipykernel_10908\2924456791.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   India_owid = owid_df[owid_df['country'] == 'India'][owid_df['year'] >= 2015]
#       iso_code country  year       co2  co2_per_capita  trade_co2  cement_co2  \
# 11272      IND   India  2015  2268.567           1.732   -190.365     117.508
# 11273      IND   India  2016  2382.223           1.799   -203.696     123.281
# 11274      IND   India  2017  2433.856           1.818   -190.634     121.047
# 11275      IND   India  2018  2599.806           1.922   -236.531     138.965
# 11276      IND   India  2019  2625.968           1.922   -215.495     143.664
# 11277      IND   India  2020  2441.792           1.769        NaN     122.908
#
#        cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 11272                  0.090  1487.726                1.136  ...
# 11273                  0.093  1530.271                1.155  ...
# ...

# %%
India_owid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 11272 to 11277
# Data columns (total 60 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   iso_code                             6 non-null      object
#  1   country                              6 non-null      object
#  2   year                                 6 non-null      int64
#  3   co2                                  6 non-null      float64
#  4   co2_per_capita                       6 non-null      float64
#  5   trade_co2                            5 non-null      float64
#  6   cement_co2                           6 non-null      float64
#  7   cement_co2_per_capita                6 non-null      float64
#  8   coal_co2                             6 non-null      float64
#  9   coal_co2_per_capita                  6 non-null      float64
#  10  flaring_co2                          6 non-null      float64
# ...

# %%
India_owid['co2']
# Out:
# 11272    2268.567
# 11273    2382.223
# 11274    2433.856
# 11275    2599.806
# 11276    2625.968
# 11277    2441.792
# Name: co2, dtype: float64
